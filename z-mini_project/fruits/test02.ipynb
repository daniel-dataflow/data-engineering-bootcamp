# %%
import torch
import os # os 모듈 추가

# 1. 로컬 yolov5 폴더 경로 설정
# 'test.ipynb'는 'fruits' 폴더 안에 있습니다.
# 'yolov5' 폴더는 상위 폴더('z-mini_project')에 있으므로
# 경로는 '../yolov5'가 됩니다.
local_yolov5_path = '../yolov5' 

# 2. 모델 로드 (source='local' 옵션 사용)
model = torch.hub.load(
    local_yolov5_path,    # 인터넷 대신 로컬 폴더 경로를 지정
    'yolov5s',            # 로드할 모델 이름
    source='local',       # ★★★ 'local' 소스를 사용한다고 명시 ★★★
    pretrained=True       # 미리 학습된 가중치 사용
)

# 3. 추론 실행 (이전과 동일)
sample_image = processed_data[0]['image']
result = model(sample_image)

# 4. 결과 출력 (이전과 동일)
print(result.pandas().xyxy[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 11
#       8 local_yolov5_path = '../yolov5'
#      10 # 2. 모델 로드 (source='local' 옵션 사용)
# ---> 11 model = torch.hub.load(
#      12     local_yolov5_path,    # 인터넷 대신 로컬 폴더 경로를 지정
#      13     'yolov5s',            # 로드할 모델 이름
#      14     source='local',       # ★★★ 'local' 소스를 사용한다고 명시 ★★★
#      15     pretrained=True       # 미리 학습된 가중치 사용
#      16 )
#      18 # 3. 추론 실행 (이전과 동일)
#      19 sample_image = processed_data[0]['image']
#
# File ~/dev/data-engineer/miniconda3/envs/yolov5_env/lib/python3.10/site-packages/torch/hub.py:652, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     642 if source == "github":
#     643     repo_or_dir = _get_cache_or_reload(
#     644         repo_or_dir,
#     645         force_reload,
#    (...)
#     649         skip_validation=skip_validation,
#     650     )
# --> 652 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     653 return model
#
# File ~/dev/data-engineer/miniconda3/envs/yolov5_env/lib/python3.10/site-packages/torch/hub.py:685, in _load_local(hubconf_dir, model, *args, **kwargs)
#     682     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     684     entry = _load_entry_from_hubconf(hub_module, model)
# --> 685     model = entry(*args, **kwargs)
#     687 return model
#
# File ~/dev/data-engineer/workspaces/z-mini_project/fruits/../yolov5/hubconf.py:213, in yolov5s(pretrained, channels, classes, autoshape, _verbose, device)
#     175 def yolov5s(pretrained=True, channels=3, classes=80, autoshape=True, _verbose=True, device=None):
#     176     """Create a YOLOv5-small (yolov5s) model with options for pretraining, input channels, class count, autoshaping,
#     177     verbosity, and device configuration.
#     178
#    (...)
#     211         the [YOLOv5 PyTorch Hub Documentation](https://pytorch.org/hub/ultralytics_yolov5/).
#     212     """
# --> 213     return _create("yolov5s", pretrained, channels, classes, autoshape, _verbose, device)
#
# File ~/dev/data-engineer/workspaces/z-mini_project/fruits/../yolov5/hubconf.py:55, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      17 """Creates or loads a YOLOv5 model, with options for pretrained weights and model customization.
#      18
#      19 Args:
#    (...)
#      51     [YOLOv5 PyTorch Hub Documentation](https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading/).
#      52 """
#      53 from pathlib import Path
# ---> 55 from models.common import AutoShape, DetectMultiBackend
#      56 from models.experimental import attempt_load
#      57 from models.yolo import ClassificationModel, DetectionModel, SegmentationModel
#
# File ~/dev/data-engineer/workspaces/z-mini_project/fruits/../yolov5/models/common.py:18
#      16 import cv2
#      17 import numpy as np
# ---> 18 import pandas as pd
#      19 import requests
#      20 import torch
#
# ModuleNotFoundError: No module named 'pandas'
