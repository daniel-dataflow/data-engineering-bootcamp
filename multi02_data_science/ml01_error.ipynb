# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([4, 7, 10, 13, 16])

# y = 3 * x + 1

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([3, 4, 10, 14, 17])

# %%
fx01 = 3 * x + 1

# %%
# 실제값 ㅛ - 예측값 fx01의 차이
fx01_error = y - fx01

# %%
plt.plot(x, fx01)

for i in range(len(x)):
    hx = np.array([x[i], x[i]])
    hy = np.array([fx01[i], y[i]])
    plt.plot(hx, hy, marker="o")

plt.show()

# %%
fx02 = np.full((x.shape), 10)
fx02
# Out:
# array([10, 10, 10, 10, 10])

# %%
fx02_error = y - fx02
fx02_error
# Out:
# array([-7, -6,  0,  4,  7])

# %%
plt.plot(x, fx02)

for i in range(len(x)):
    hx = np.array([x[i], x[i]])
    hy = np.array([fx02[i], y[i]])
    plt.plot(hx, hy, marker="o")

plt.show()

# %%
print(np.sum(fx01_error))
print(np.sum(fx02_error))
# Out:
# -2
# -2

# %%
"""
Mean Squared Error (평균 제곱 오차)
-> ((오타들의 제곱)들을 모두 더하자) 평균내자
"""
def mean_squared_error(a, b, x, y):
    return ( (y - (a * x + b))** 2 ).mean()

# %%
# fx01 = 3 * x + 1
mean_squared_error(3, 1, x, y)
# Out:
# np.float64(2.4)

# %%
# fx02 = 0 * x + 10
mean_squared_error(0, 10, x, y)
# Out:
# np.float64(30.0)
