# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /Users/handaeseong/dev/data-engineer/miniconda3/envs/multi02/lib/python3.14/site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in /Users/handaeseong/dev/data-engineer/miniconda3/envs/multi02/lib/python3.14/site-packages (from scikit-learn) (1.16.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp314-cp314-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 22.0 MB/s  0:00:00 eta 0:00:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# 1. dataset 준비
x = 10 * np.random.rand(100, 1)
y = 3 * x + 1 + np.random.randn(100, 1)

print(x)    
print(y)
# Out:
# [[5.64100448]
#  [2.33257383]
#  [0.35166253]
#  [4.39988792]
#  [3.06056667]
#  [5.07268617]
#  [0.41638298]
#  [1.90264959]
#  [9.33226651]
#  [8.80543813]
#  [0.65610078]
#  [9.1843432 ]
#  [0.90727452]
#  [8.90790946]
#  [6.21678904]
#  [9.27492709]
#  [0.3812508 ]
#  [3.69298823]
#  [9.87798075]
#  [2.51985934]
#  [3.83818957]
#  [4.69636318]
#  [6.68025328]
#  [6.22686023]
#  [7.84726092]
#  [7.55445827]
#  [5.94283254]
#  [8.31873732]
#  [7.28527709]
#  [4.1290773 ]
#  [7.18241685]
#  [1.66459671]
#  [8.89785206]
#  [2.12934674]
#  [1.99989207]
#  [5.25780312]
#  [0.53007707]
#  [0.7370074 ]
#  [5.96798932]
#  [2.25347049]
#  [9.5664915 ]
#  [9.03379906]
#  [1.40743168]
#  [8.66570244]
#  [8.66863661]
#  [0.33489809]
#  [3.50022763]
#  [7.15079044]
#  [6.65151101]
#  [8.92315187]
#  [9.00630023]
#  [6.14728368]
#  [6.38855698]
#  [8.42001356]
#  [6.55401817]
#  [1.62597359]
#  [1.58260147]
#  [3.02083771]
#  [8.55150908]
#  [5.90273996]
#  [1.85794947]
#  [5.09698668]
#  [6.07830738]
#  [8.3719224 ]
#  [4.48916891]
#  [7.40284301]
#  [3.28176382]
#  [2.26610083]
#  [2.73559368]
#  [7.35234561]
#  [8.17834896]
#  [6.01704601]
#  [5.16782245]
#  [6.91816086]
#  [0.45451255]
#  [8.55619012]
#  [6.63605496]
#  [3.43638025]
#  [4.2241225 ]
#  [0.07766615]
#  [2.92359925]
#  [8.6482415 ]
#  [9.7383735 ]
#  [1.70751583]
#  [6.09023378]
#  [9.76188583]
#  [7.15119928]
#  [2.16440174]
#  [9.1691173 ]
#  [7.90922015]
#  [8.9076047 ]
#  [3.48705443]
#  [2.5247683 ]
#  [4.68931417]
#  [4.7192008 ]
#  [1.17306488]
#  [4.01726403]
#  [6.65966511]
#  [4.49743874]
#  [9.29561293]]
# [[17.52412691]
#  [ 8.30486953]
#  [ 0.15541235]
#  [14.56527876]
#  [ 8.5895132 ]
#  [15.17415305]
#  [ 3.27969524]
#  [ 8.04727022]
#  [29.08159574]
#  [28.54256226]
#  [ 2.82126996]
#  [29.71063431]
#  [ 4.12770905]
#  [28.13473096]
#  [19.71997859]
#  [28.6998003 ]
#  [ 2.47174064]
#  [12.34134799]
#  [28.87153115]
#  [ 8.80231323]
#  [11.6190725 ]
#  [13.58460372]
#  [22.10738626]
#  [22.08298688]
#  [24.04046606]
#  [23.16549005]
#  [19.92014695]
#  [24.90594527]
#  [23.87633185]
#  [12.52815015]
#  [22.21825917]
#  [ 7.37204907]
#  [26.80292805]
#  [ 6.02367973]
#  [ 7.4632515 ]
#  [17.45050771]
#  [ 2.11252267]
#  [ 3.9721175 ]
#  [19.23784179]
#  [ 7.23479572]
#  [28.9379954 ]
#  [27.96643239]
#  [ 4.88282228]
#  [28.83001292]
#  [26.20496393]
#  [ 1.62206328]
#  [11.9724779 ]
#  [22.04833098]
#  [20.65904034]
#  [27.81777751]
#  [26.45372909]
#  [20.65075347]
#  [20.01980144]
#  [26.27983687]
#  [22.19683795]
#  [ 7.37289788]
#  [ 4.25593432]
#  [11.91226656]
#  [27.74937818]
#  [16.93961431]
#  [ 6.44103887]
#  [15.65483233]
#  [20.30967963]
#  [25.87119391]
#  [13.76643218]
#  [23.24411032]
#  [12.96480336]
#  [ 7.35805302]
#  [ 8.77423112]
#  [22.54177703]
#  [25.15885169]
#  [18.34838743]
#  [14.73928625]
#  [22.96010371]
#  [ 2.67516257]
#  [28.29530668]
#  [21.2615056 ]
#  [ 9.8906691 ]
#  [15.57755436]
#  [ 1.75286276]
#  [ 9.55505751]
#  [26.58313559]
#  [31.39037527]
#  [ 5.71936857]
#  [19.69017861]
#  [31.62948452]
#  [22.12469625]
#  [ 6.52037623]
#  [28.66398089]
#  [25.21836847]
#  [28.9992767 ]
#  [11.58096764]
#  [ 8.77429391]
#  [15.51240737]
#  [14.56000145]
#  [ 4.49516712]
#  [12.90205683]
#  [21.82682966]
#  [14.97382895]
#  [30.3518821 ]]

# %%
plt.scatter(x, y)

# %%
# 2. 데이터 분할
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3, random_state=1)
# 학습용
print(train_x.shape)
print(train_y.shape)
# Out:
# (70, 1)
# (70, 1)

# %%
# 검증용
print(test_x.shape)
print(test_y.shape)
# Out:
# (30, 1)
# (30, 1)

# %%
# 3. model 선택
model = LinearRegression()

# %%
# 4. 학습
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
# 예측
predict = model.predict(test_x)
predict
# Out:
# array([[ 9.84603533],
#        [19.38944777],
#        [ 7.45236497],
#        [27.09861737],
#        [15.1674406 ],
#        [12.16477349],
#        [ 2.63258236],
#        [30.38399151],
#        [23.19312439],
#        [23.34531039],
#        [ 8.64406263],
#        [ 7.82644163],
#        [ 5.80461698],
#        [20.28851624],
#        [19.5613813 ],
#        [27.85087863],
#        [ 6.05172932],
#        [27.16008292],
#        [13.76547399],
#        [ 3.01238503],
#        [ 2.09488736],
#        [21.88460452],
#        [21.1055656 ],
#        [19.3535047 ],
#        [ 8.6292683 ],
#        [16.88071839],
#        [15.25751114],
#        [26.1055775 ],
#        [11.58384323],
#        [19.02103476]])

# %%
plt.plot(test_x, test_y, "o")
plt.plot(test_x, predict)
plt.show()
