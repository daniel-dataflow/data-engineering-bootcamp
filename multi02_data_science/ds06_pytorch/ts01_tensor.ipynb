# %%
# Mac OS버전
# %pip install torch torchvision
# Windows 버전
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.24.0%2Bcu126-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\daniel\miniconda3\envs\multi02\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\daniel\miniconda3\envs\multi02\lib\site-packages (from torchvision) (2.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\daniel\miniconda3\envs\multi02\lib\site-packages (from torchvision) (11.3.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ---------------------------------------- 536.2/536.2 kB 5.8 MB/s  0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Downloading https://download.pytorch.org/whl/cu126/torch-2.9.0%2Bcu126-cp311-cp311-win_amd64.whl (2582.7 MB)
#    ---------------------------------------- 0.0/2.6 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 GB 60.7 MB/s eta 0:00:43
#    ---------------------------------------- 0.0/2.6 GB 60.5 MB/s eta 0:00:43
#     --------------------------------------- 0.0/2.6 GB 60.0 MB/s eta 0:00:43
#     --------------------------------------- 0.1/2.6 GB 60.2 MB/s eta 0:00:43
#     --------------------------------------- 0.1/2.6 GB 59.2 MB/s eta 0:00:43
#    - -------------------------------------- 0.1/2.6 GB 59.8 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 59.4 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 59.6 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 59.6 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 59.3 MB/s eta 0:00:42
#    -- ------------------------------------- 0.1/2.6 GB 59.5 MB/s eta 0:00:42
#    -- ------------------------------------- 0.2/2.6 GB 59.3 MB/s eta 0:00:41
#    -- ------------------------------------- 0.2/2.6 GB 59.4 MB/s eta 0:00:41
#    -- ------------------------------------- 0.2/2.6 GB 59.4 MB/s eta 0:00:41
#    -- ------------------------------------- 0.2/2.6 GB 59.3 MB/s eta 0:00:41
#    --- ------------------------------------ 0.2/2.6 GB 59.2 MB/s eta 0:00:41
#    --- ------------------------------------ 0.2/2.6 GB 59.3 MB/s eta 0:00:40
#    --- ------------------------------------ 0.2/2.6 GB 59.3 MB/s eta 0:00:40
#    --- ------------------------------------ 0.2/2.6 GB 59.1 MB/s eta 0:00:40
#    --- ------------------------------------ 0.3/2.6 GB 59.3 MB/s eta 0:00:40
#    ---- ----------------------------------- 0.3/2.6 GB 58.2 MB/s eta 0:00:40
#    ---- ----------------------------------- 0.3/2.6 GB 56.1 MB/s eta 0:00:42
#    ---- ----------------------------------- 0.3/2.6 GB 54.9 MB/s eta 0:00:43
#    ---- ----------------------------------- 0.3/2.6 GB 53.5 MB/s eta 0:00:44
#    ---- ----------------------------------- 0.3/2.6 GB 52.9 MB/s eta 0:00:44
#    ---- ----------------------------------- 0.3/2.6 GB 53.0 MB/s eta 0:00:43
#    ---- ----------------------------------- 0.3/2.6 GB 53.0 MB/s eta 0:00:43
#    ----- ---------------------------------- 0.3/2.6 GB 51.9 MB/s eta 0:00:44
#    ----- ---------------------------------- 0.3/2.6 GB 51.6 MB/s eta 0:00:44
#    ----- ---------------------------------- 0.3/2.6 GB 51.4 MB/s eta 0:00:44
#    ----- ---------------------------------- 0.4/2.6 GB 50.2 MB/s eta 0:00:45
#    ----- ---------------------------------- 0.4/2.6 GB 50.0 MB/s eta 0:00:45
#    ----- ---------------------------------- 0.4/2.6 GB 50.0 MB/s eta 0:00:45
#    ------ --------------------------------- 0.4/2.6 GB 49.9 MB/s eta 0:00:44
#    ------ --------------------------------- 0.4/2.6 GB 49.7 MB/s eta 0:00:44
#    ------ --------------------------------- 0.4/2.6 GB 49.9 MB/s eta 0:00:44
#    ------ --------------------------------- 0.4/2.6 GB 49.9 MB/s eta 0:00:44
#    ------ --------------------------------- 0.4/2.6 GB 49.7 MB/s eta 0:00:44
#    ------- -------------------------------- 0.5/2.6 GB 49.7 MB/s eta 0:00:43
#    ------- -------------------------------- 0.5/2.6 GB 49.6 MB/s eta 0:00:43
#    ------- -------------------------------- 0.5/2.6 GB 49.4 MB/s eta 0:00:43
#    ------- -------------------------------- 0.5/2.6 GB 49.6 MB/s eta 0:00:43
#    ------- -------------------------------- 0.5/2.6 GB 49.7 MB/s eta 0:00:42
#    ------- -------------------------------- 0.5/2.6 GB 49.4 MB/s eta 0:00:42
#    -------- ------------------------------- 0.5/2.6 GB 52.0 MB/s eta 0:00:40
#    -------- ------------------------------- 0.5/2.6 GB 53.9 MB/s eta 0:00:38
#    -------- ------------------------------- 0.6/2.6 GB 54.9 MB/s eta 0:00:37
#    -------- ------------------------------- 0.6/2.6 GB 54.8 MB/s eta 0:00:37
#    -------- ------------------------------- 0.6/2.6 GB 54.8 MB/s eta 0:00:37
#    --------- ------------------------------ 0.6/2.6 GB 56.4 MB/s eta 0:00:36
#    --------- ------------------------------ 0.6/2.6 GB 56.6 MB/s eta 0:00:35
#    --------- ------------------------------ 0.6/2.6 GB 58.4 MB/s eta 0:00:34
#    --------- ------------------------------ 0.6/2.6 GB 58.8 MB/s eta 0:00:34
#    --------- ------------------------------ 0.6/2.6 GB 59.0 MB/s eta 0:00:33
#    ---------- ----------------------------- 0.7/2.6 GB 58.8 MB/s eta 0:00:33
#    ---------- ----------------------------- 0.7/2.6 GB 58.6 MB/s eta 0:00:33
#    ---------- ----------------------------- 0.7/2.6 GB 58.8 MB/s eta 0:00:33
#    ---------- ----------------------------- 0.7/2.6 GB 58.8 MB/s eta 0:00:33
#    ---------- ----------------------------- 0.7/2.6 GB 58.6 MB/s eta 0:00:33
#    ----------- ---------------------------- 0.7/2.6 GB 58.6 MB/s eta 0:00:32
#    ----------- ---------------------------- 0.7/2.6 GB 59.0 MB/s eta 0:00:32
#    ----------- ---------------------------- 0.7/2.6 GB 59.0 MB/s eta 0:00:32
#    ----------- ---------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:31
#    ----------- ---------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:31
#    ------------ --------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:31
#    ------------ --------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:31
#    ------------ --------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:30
#    ------------ --------------------------- 0.8/2.6 GB 59.2 MB/s eta 0:00:30
#    ------------ --------------------------- 0.8/2.6 GB 58.6 MB/s eta 0:00:30
#    ------------ --------------------------- 0.8/2.6 GB 56.6 MB/s eta 0:00:31
#    ------------- -------------------------- 0.8/2.6 GB 56.4 MB/s eta 0:00:31
#    ------------- -------------------------- 0.9/2.6 GB 56.6 MB/s eta 0:00:31
#    ------------- -------------------------- 0.9/2.6 GB 56.4 MB/s eta 0:00:31
#    ------------- -------------------------- 0.9/2.6 GB 56.6 MB/s eta 0:00:31
#    ------------- -------------------------- 0.9/2.6 GB 56.4 MB/s eta 0:00:30
#    -------------- ------------------------- 0.9/2.6 GB 56.6 MB/s eta 0:00:30
#    -------------- ------------------------- 0.9/2.6 GB 56.4 MB/s eta 0:00:30
#    -------------- ------------------------- 0.9/2.6 GB 56.4 MB/s eta 0:00:30
#    -------------- ------------------------- 0.9/2.6 GB 56.4 MB/s eta 0:00:30
#    -------------- ------------------------- 1.0/2.6 GB 56.6 MB/s eta 0:00:29
#    --------------- ------------------------ 1.0/2.6 GB 56.4 MB/s eta 0:00:29
#    --------------- ------------------------ 1.0/2.6 GB 56.4 MB/s eta 0:00:29
#    --------------- ------------------------ 1.0/2.6 GB 56.4 MB/s eta 0:00:29
#    --------------- ------------------------ 1.0/2.6 GB 56.2 MB/s eta 0:00:28
#    --------------- ------------------------ 1.0/2.6 GB 56.1 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.0/2.6 GB 56.1 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.0/2.6 GB 56.2 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.1/2.6 GB 56.2 MB/s eta 0:00:28
#    ---------------- ----------------------- 1.1/2.6 GB 56.1 MB/s eta 0:00:27
#    ---------------- ----------------------- 1.1/2.6 GB 56.1 MB/s eta 0:00:27
#    ----------------- ---------------------- 1.1/2.6 GB 58.6 MB/s eta 0:00:26
#    ----------------- ---------------------- 1.1/2.6 GB 58.6 MB/s eta 0:00:26
#    ----------------- ---------------------- 1.1/2.6 GB 58.6 MB/s eta 0:00:25
#    ----------------- ---------------------- 1.1/2.6 GB 58.8 MB/s eta 0:00:25
#    ----------------- ---------------------- 1.2/2.6 GB 58.8 MB/s eta 0:00:25
#    ------------------ --------------------- 1.2/2.6 GB 58.6 MB/s eta 0:00:25
#    ------------------ --------------------- 1.2/2.6 GB 58.4 MB/s eta 0:00:25
#    ------------------ --------------------- 1.2/2.6 GB 58.4 MB/s eta 0:00:24
#    ------------------ --------------------- 1.2/2.6 GB 58.0 MB/s eta 0:00:24
#    ------------------ --------------------- 1.2/2.6 GB 58.0 MB/s eta 0:00:24
#    ------------------ --------------------- 1.2/2.6 GB 58.2 MB/s eta 0:00:24
#    ------------------- -------------------- 1.2/2.6 GB 57.4 MB/s eta 0:00:24
#    ------------------- -------------------- 1.2/2.6 GB 57.6 MB/s eta 0:00:24
#    ------------------- -------------------- 1.3/2.6 GB 57.6 MB/s eta 0:00:23
#    ------------------- -------------------- 1.3/2.6 GB 57.2 MB/s eta 0:00:23
#    ------------------- -------------------- 1.3/2.6 GB 57.4 MB/s eta 0:00:23
#    -------------------- ------------------- 1.3/2.6 GB 57.2 MB/s eta 0:00:23
#    -------------------- ------------------- 1.3/2.6 GB 57.2 MB/s eta 0:00:23
#    -------------------- ------------------- 1.3/2.6 GB 57.4 MB/s eta 0:00:22
#    -------------------- ------------------- 1.3/2.6 GB 57.4 MB/s eta 0:00:22
#    -------------------- ------------------- 1.4/2.6 GB 57.2 MB/s eta 0:00:22
#    --------------------- ------------------ 1.4/2.6 GB 57.2 MB/s eta 0:00:22
#    --------------------- ------------------ 1.4/2.6 GB 57.2 MB/s eta 0:00:22
#    --------------------- ------------------ 1.4/2.6 GB 57.2 MB/s eta 0:00:21
#    --------------------- ------------------ 1.4/2.6 GB 57.2 MB/s eta 0:00:21
#    --------------------- ------------------ 1.4/2.6 GB 56.2 MB/s eta 0:00:21
#    --------------------- ------------------ 1.4/2.6 GB 54.8 MB/s eta 0:00:22
#    ---------------------- ----------------- 1.4/2.6 GB 55.0 MB/s eta 0:00:22
#    ---------------------- ----------------- 1.4/2.6 GB 55.3 MB/s eta 0:00:21
#    ---------------------- ----------------- 1.5/2.6 GB 54.9 MB/s eta 0:00:21
#    ---------------------- ----------------- 1.5/2.6 GB 55.3 MB/s eta 0:00:21
#    ---------------------- ----------------- 1.5/2.6 GB 55.3 MB/s eta 0:00:20
#    ----------------------- ---------------- 1.5/2.6 GB 55.3 MB/s eta 0:00:20
#    ----------------------- ---------------- 1.5/2.6 GB 55.9 MB/s eta 0:00:20
#    ----------------------- ---------------- 1.5/2.6 GB 55.9 MB/s eta 0:00:20
#    ----------------------- ---------------- 1.5/2.6 GB 56.2 MB/s eta 0:00:19
#    ----------------------- ---------------- 1.5/2.6 GB 55.9 MB/s eta 0:00:19
#    ------------------------ --------------- 1.6/2.6 GB 55.1 MB/s eta 0:00:19
#    ------------------------ --------------- 1.6/2.6 GB 55.1 MB/s eta 0:00:19
#    ------------------------ --------------- 1.6/2.6 GB 55.1 MB/s eta 0:00:19
#    ------------------------ --------------- 1.6/2.6 GB 54.8 MB/s eta 0:00:19
#    ------------------------ --------------- 1.6/2.6 GB 54.6 MB/s eta 0:00:18
#    ------------------------ --------------- 1.6/2.6 GB 54.6 MB/s eta 0:00:18
#    ------------------------- -------------- 1.6/2.6 GB 54.6 MB/s eta 0:00:18
#    ------------------------- -------------- 1.6/2.6 GB 54.6 MB/s eta 0:00:18
#    ------------------------- -------------- 1.7/2.6 GB 54.6 MB/s eta 0:00:18
#    ------------------------- -------------- 1.7/2.6 GB 54.8 MB/s eta 0:00:17
#    ------------------------- -------------- 1.7/2.6 GB 57.4 MB/s eta 0:00:16
#    -------------------------- ------------- 1.7/2.6 GB 57.4 MB/s eta 0:00:16
#    -------------------------- ------------- 1.7/2.6 GB 57.2 MB/s eta 0:00:16
#    -------------------------- ------------- 1.7/2.6 GB 57.2 MB/s eta 0:00:16
#    -------------------------- ------------- 1.7/2.6 GB 57.4 MB/s eta 0:00:15
#    -------------------------- ------------- 1.7/2.6 GB 57.4 MB/s eta 0:00:15
#    --------------------------- ------------ 1.8/2.6 GB 57.2 MB/s eta 0:00:15
#    --------------------------- ------------ 1.8/2.6 GB 57.2 MB/s eta 0:00:15
#    --------------------------- ------------ 1.8/2.6 GB 57.0 MB/s eta 0:00:15
#    --------------------------- ------------ 1.8/2.6 GB 57.2 MB/s eta 0:00:14
#    --------------------------- ------------ 1.8/2.6 GB 57.4 MB/s eta 0:00:14
#    ---------------------------- ----------- 1.8/2.6 GB 58.2 MB/s eta 0:00:14
#    ---------------------------- ----------- 1.8/2.6 GB 57.8 MB/s eta 0:00:14
#    ---------------------------- ----------- 1.8/2.6 GB 57.8 MB/s eta 0:00:13
#    ---------------------------- ----------- 1.9/2.6 GB 58.2 MB/s eta 0:00:13
#    ---------------------------- ----------- 1.9/2.6 GB 58.4 MB/s eta 0:00:13
#    ----------------------------- ---------- 1.9/2.6 GB 58.6 MB/s eta 0:00:13
#    ----------------------------- ---------- 1.9/2.6 GB 58.4 MB/s eta 0:00:12
#    ----------------------------- ---------- 1.9/2.6 GB 58.4 MB/s eta 0:00:12
#    ----------------------------- ---------- 1.9/2.6 GB 58.2 MB/s eta 0:00:12
#    ----------------------------- ---------- 1.9/2.6 GB 58.2 MB/s eta 0:00:12
#    ------------------------------ --------- 1.9/2.6 GB 58.2 MB/s eta 0:00:12
#    ------------------------------ --------- 2.0/2.6 GB 58.2 MB/s eta 0:00:11
#    ------------------------------ --------- 2.0/2.6 GB 57.8 MB/s eta 0:00:11
#    ------------------------------ --------- 2.0/2.6 GB 57.8 MB/s eta 0:00:11
#    ------------------------------ --------- 2.0/2.6 GB 57.8 MB/s eta 0:00:11
#    ------------------------------- -------- 2.0/2.6 GB 57.6 MB/s eta 0:00:11
#    ------------------------------- -------- 2.0/2.6 GB 57.8 MB/s eta 0:00:10
#    ------------------------------- -------- 2.0/2.6 GB 57.2 MB/s eta 0:00:10
#    ------------------------------- -------- 2.0/2.6 GB 57.2 MB/s eta 0:00:10
#    ------------------------------- -------- 2.1/2.6 GB 57.2 MB/s eta 0:00:10
#    ------------------------------- -------- 2.1/2.6 GB 57.2 MB/s eta 0:00:10
#    -------------------------------- ------- 2.1/2.6 GB 57.0 MB/s eta 0:00:09
#    -------------------------------- ------- 2.1/2.6 GB 57.0 MB/s eta 0:00:09
#    -------------------------------- ------- 2.1/2.6 GB 57.2 MB/s eta 0:00:09
#    -------------------------------- ------- 2.1/2.6 GB 57.0 MB/s eta 0:00:09
#    -------------------------------- ------- 2.1/2.6 GB 56.8 MB/s eta 0:00:09
#    -------------------------------- ------- 2.1/2.6 GB 54.2 MB/s eta 0:00:09
#    --------------------------------- ------ 2.1/2.6 GB 53.7 MB/s eta 0:00:09
#    --------------------------------- ------ 2.1/2.6 GB 53.6 MB/s eta 0:00:09
#    --------------------------------- ------ 2.2/2.6 GB 53.6 MB/s eta 0:00:08
#    --------------------------------- ------ 2.2/2.6 GB 53.4 MB/s eta 0:00:08
#    --------------------------------- ------ 2.2/2.6 GB 53.4 MB/s eta 0:00:08
#    --------------------------------- ------ 2.2/2.6 GB 53.2 MB/s eta 0:00:08
#    ---------------------------------- ----- 2.2/2.6 GB 53.2 MB/s eta 0:00:08
#    ---------------------------------- ----- 2.2/2.6 GB 53.2 MB/s eta 0:00:07
#    ---------------------------------- ----- 2.2/2.6 GB 53.0 MB/s eta 0:00:07
#    ---------------------------------- ----- 2.2/2.6 GB 53.4 MB/s eta 0:00:07
#    ---------------------------------- ----- 2.3/2.6 GB 53.4 MB/s eta 0:00:07
#    ----------------------------------- ---- 2.3/2.6 GB 53.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.3/2.6 GB 53.2 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.3/2.6 GB 52.9 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.3/2.6 GB 52.7 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.3/2.6 GB 52.5 MB/s eta 0:00:06
#    ----------------------------------- ---- 2.3/2.6 GB 52.5 MB/s eta 0:00:05
#    ------------------------------------ --- 2.3/2.6 GB 52.5 MB/s eta 0:00:05
#    ------------------------------------ --- 2.3/2.6 GB 52.5 MB/s eta 0:00:05
#    ------------------------------------ --- 2.4/2.6 GB 52.4 MB/s eta 0:00:05
#    ------------------------------------ --- 2.4/2.6 GB 52.7 MB/s eta 0:00:05
#    ------------------------------------ --- 2.4/2.6 GB 52.7 MB/s eta 0:00:04
#    ------------------------------------- -- 2.4/2.6 GB 55.3 MB/s eta 0:00:04
#    ------------------------------------- -- 2.4/2.6 GB 55.7 MB/s eta 0:00:04
#    ------------------------------------- -- 2.4/2.6 GB 55.5 MB/s eta 0:00:03
#    ------------------------------------- -- 2.4/2.6 GB 55.3 MB/s eta 0:00:03
#    ------------------------------------- -- 2.4/2.6 GB 55.3 MB/s eta 0:00:03
#    ------------------------------------- -- 2.5/2.6 GB 54.9 MB/s eta 0:00:03
#    -------------------------------------- - 2.5/2.6 GB 54.6 MB/s eta 0:00:03
#    -------------------------------------- - 2.5/2.6 GB 54.6 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 54.2 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 53.7 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 53.4 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 53.2 MB/s eta 0:00:02
#    ---------------------------------------  2.5/2.6 GB 53.0 MB/s eta 0:00:02
#    ---------------------------------------  2.5/2.6 GB 53.2 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.4 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.4 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.2 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 53.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 GB 21.7 MB/s  0:00:53
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.24.0%2Bcu126-cp311-cp311-win_amd64.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#    ---------------------------------------- 8.5/8.5 MB 40.7 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading https://download.pytorch.org/whl/networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.3 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 29.7 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---------------------------------------- 0/9 [mpmath]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    ---- ----------------------------------- 1/9 [sympy]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    -------- ------------------------------- 2/9 [networkx]
#    ------------- -------------------------- 3/9 [MarkupSafe]
#    ----------------- ---------------------- 4/9 [fsspec]
#    ----------------- ---------------------- 4/9 [fsspec]
#    ----------------- ---------------------- 4/9 [fsspec]
#    ----------------- ---------------------- 4/9 [fsspec]
#    ----------------- ---------------------- 4/9 [fsspec]
#    ---------------------- ----------------- 5/9 [filelock]
#    -------------------------- ------------- 6/9 [jinja2]
#    -------------------------- ------------- 6/9 [jinja2]
#    -------------------------- ------------- 6/9 [jinja2]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
# ...
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ---------------------------------------- 9/9 [torchvision]
#
# Successfully installed MarkupSafe-2.1.5 filelock-3.19.1 fsspec-2025.9.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 sympy-1.14.0 torch-2.9.0+cu126 torchvision-0.24.0+cu126
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
# GPU 사용 할 수 있는 여부
torch.cuda.is_available()
# Out:
# False

# %%
torch.__version__
# Out:
# '2.9.0'

# %%
import numpy as np

# %%
data = [[1, 2],
        [3, 4]]

# %%
x = torch.tensor(data)
x
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
# 넘파이 경우 텐서파일로 만든 방법
x_np = np.array(x)

x_tensor = torch.from_numpy(x_np)
x_tensor
# Out:
# /var/folders/s3/2n7b_c090wn9dg5gvs55lrtr0000gn/T/ipykernel_95028/2376230143.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x_np = np.array(x)
# tensor([[1, 2],
#         [3, 4]])

# %%
x[0]
# Out:
# tensor([1, 2])

# %%
x[0][0]
# Out:
# tensor(1)

# %%
# shape
x.size()
# Out:
# torch.Size([2, 2])

# %%
# 터치 객체
x[0].size()
# Out:
# torch.Size([2])

# %%
# 그냥 값
x.size(0)
# Out:
# 2

# %%
y = torch.tensor(np.array([[5, 6],[7, 8]]))

# %%
x + y
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
torch.add(x, y)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
x.add(y)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
y
# Out:
# tensor([[5, 6],
#         [7, 8]])

# %%
# inplace=True , 원본에다가 수정한 값을 그대로 넣는것, 판다스 데이터 프레임에서 inplace 사용됨 
y.add_(x)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
y
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
# view : reshape 해줌
x_reshape01 = x.view(4)
x_reshape01
# Out:
# tensor([1, 2, 3, 4])

# %%
x_reshape02 = x.view(-1)
x_reshape02
# Out:
# tensor([1, 2, 3, 4])

# %%
x_to_np = x.numpy()
x_to_np
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
type(x_to_np)
# Out:
# numpy.ndarray

# %%
# 텐서 객체를 넘파이로 바꾼다.
type(x)
# Out:
# torch.Tensor
