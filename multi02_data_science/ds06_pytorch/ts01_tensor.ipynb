# %%
# Mac OS버전
# %pip install torch torchvision
# Windows 버전
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
import torch

# %%
# GPU 사용 할 수 있는 여부
torch.cuda.is_available()
# Out:
# False

# %%
torch.__version__
# Out:
# '2.9.0'

# %%
import numpy as np

# %%
data = [[1, 2],
        [3, 4]]

# %%
x = torch.tensor(data)
x
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
# 넘파이 경우 텐서파일로 만든 방법
x_np = np.array(x)

x_tensor = torch.from_numpy(x_np)
x_tensor
# Out:
# /var/folders/s3/2n7b_c090wn9dg5gvs55lrtr0000gn/T/ipykernel_46327/1647259491.py:2: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   x_np = np.array(x)
# tensor([[1, 2],
#         [3, 4]])

# %%
x[0]
# Out:
# tensor([1, 2])

# %%
x[0][0]
# Out:
# tensor(1)

# %%
# shape
x.size()
# Out:
# torch.Size([2, 2])

# %%
# 터치 객체
x[0].size()
# Out:
# torch.Size([2])

# %%
# 그냥 값
x.size(0)
# Out:
# 2

# %%
y = torch.tensor(np.array([[5, 6],[7, 8]]))

# %%
x + y
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
torch.add(x, y)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
x.add(y)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
y
# Out:
# tensor([[5, 6],
#         [7, 8]])

# %%
# inplace=True , 원본에다가 수정한 값을 그대로 넣는것, 판다스 데이터 프레임에서 inplace 사용됨 
y.add_(x)
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
y
# Out:
# tensor([[ 6,  8],
#         [10, 12]])

# %%
# view : reshape 해줌
x_reshape01 = x.view(4)
x_reshape01
# Out:
# tensor([1, 2, 3, 4])

# %%
x_reshape02 = x.view(-1)
x_reshape02
# Out:
# tensor([1, 2, 3, 4])

# %%
x_to_np = x.numpy()
x_to_np
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
type(x_to_np)
# Out:
# numpy.ndarray

# %%
# 텐서 객체를 넘파이로 바꾼다.
type(x)
# Out:
# torch.Tensor
