# %% [markdown]
# NLP (Natural Language Processing) : 자연어 처리

# %%
with open("../datasets/shakespeare.txt") as f:
    shakespeare = f.readlines()

shakespeare
# Out:
# ['THE SONNETS\n',
#  '\n',
#  'by William Shakespeare\n',
#  '\n',
#  'From fairest creatures we desire increase,\n',
#  "That thereby beauty's rose might never die,\n",
#  'But as the riper should by time decease,\n',
#  'His tender heir might bear his memory:\n',
#  'But thou contracted to thine own bright eyes,\n',
#  "Feed'st thy light's flame with self-substantial fuel,\n",
#  'Making a famine where abundance lies,\n',
#  'Thy self thy foe, to thy sweet self too cruel:\n',
#  "Thou that art now the world's fresh ornament,\n",
#  'And only herald to the gaudy spring,\n',
#  'Within thine own bud buriest thy content,\n',
#  "And tender churl mak'st waste in niggarding:\n",
#  'Pity the world, or else this glutton be,\n',
#  "To eat the world's due, by the grave and thee.\n",
#  '\n',
#  'When forty winters shall besiege thy brow,\n',
#  "And dig deep trenches in thy beauty's field,\n",
#  "Thy youth's proud livery so gazed on now,\n",
# ...

# %%
# 공백으로 거대한 문장으로 만들었다.
tokens = " ".join(shakespeare)

# %%
# 소문자로 변경
tokens = tokens.lower()

# %%
# \n  제거
tokens = tokens.replace("\n", "")
tokens
# Out:
# "the sonnets  by william shakespeare  from fairest creatures we desire increase, that thereby beauty's rose might never die, but as the riper should by time decease, his tender heir might bear his memory: but thou contracted to thine own bright eyes, feed'st thy light's flame with self-substantial fuel, making a famine where abundance lies, thy self thy foe, to thy sweet self too cruel: thou that art now the world's fresh ornament, and only herald to the gaudy spring, within thine own bud buriest thy content, and tender churl mak'st waste in niggarding: pity the world, or else this glutton be, to eat the world's due, by the grave and thee.  when forty winters shall besiege thy brow, and dig deep trenches in thy beauty's field, thy youth's proud livery so gazed on now, will be a tattered weed of small worth held:   then being asked, where all thy beauty lies, where all the treasure of thy lusty days; to say within thine own deep sunken eyes, were an all-eating shame, and thriftless pr
# ...

# %%
import re

# %%
# a부터 z까지 아닌 것들을 공백으로 변경해줘.
tokens = re.sub("[^a-z]", " ", tokens)
tokens
# Out:
# 'the sonnets  by william shakespeare  from fairest creatures we desire increase  that thereby beauty s rose might never die  but as the riper should by time decease  his tender heir might bear his memory  but thou contracted to thine own bright eyes  feed st thy light s flame with self substantial fuel  making a famine where abundance lies  thy self thy foe  to thy sweet self too cruel  thou that art now the world s fresh ornament  and only herald to the gaudy spring  within thine own bud buriest thy content  and tender churl mak st waste in niggarding  pity the world  or else this glutton be  to eat the world s due  by the grave and thee   when forty winters shall besiege thy brow  and dig deep trenches in thy beauty s field  thy youth s proud livery so gazed on now  will be a tattered weed of small worth held    then being asked  where all thy beauty lies  where all the treasure of thy lusty days  to say within thine own deep sunken eyes  were an all eating shame  and thriftless pr
# ...

# %%
tokens =tokens.split(" ")

# %%
tokens
# Out:
# ['the',
#  'sonnets',
#  '',
#  'by',
#  'william',
#  'shakespeare',
#  '',
#  'from',
#  'fairest',
#  'creatures',
#  'we',
#  'desire',
#  'increase',
#  '',
#  'that',
#  'thereby',
#  'beauty',
#  's',
#  'rose',
#  'might',
#  'never',
#  'die',
#  '',
#  'but',
#  'as',
#  'the',
#  'riper',
#  'should',
#  'by',
#  'time',
#  'decease',
#  '',
#  'his',
#  'tender',
#  'heir',
#  'might',
#  'bear',
#  'his',
#  'memory',
#  '',
#  'but',
#  'thou',
#  'contracted',
#  'to',
#  'thine',
#  'own',
#  'bright',
#  'eyes',
#  '',
#  'feed',
#  'st',
#  'thy',
#  'light',
#  's',
#  'flame',
#  'with',
#  'self',
#  'substantial',
#  'fuel',
#  '',
#  'making',
#  'a',
#  'famine',
#  'where',
#  'abundance',
#  'lies',
#  '',
#  'thy',
#  'self',
#  'thy',
#  'foe',
#  '',
#  'to',
#  'thy',
#  'sweet',
#  'self',
#  'too',
#  'cruel',
#  '',
#  'thou',
#  'that',
#  'art',
#  'now',
#  'the',
#  'world',
#  's',
#  'fresh',
#  'ornament',
#  '',
#  'and',
#  'only',
# ...

# %%
# '', 삭제
tokens = list(filter(None, tokens))
tokens
# Out:
# ['the',
#  'sonnets',
#  'by',
#  'william',
#  'shakespeare',
#  'from',
#  'fairest',
#  'creatures',
#  'we',
#  'desire',
#  'increase',
#  'that',
#  'thereby',
#  'beauty',
#  's',
#  'rose',
#  'might',
#  'never',
#  'die',
#  'but',
#  'as',
#  'the',
#  'riper',
#  'should',
#  'by',
#  'time',
#  'decease',
#  'his',
#  'tender',
#  'heir',
#  'might',
#  'bear',
#  'his',
#  'memory',
#  'but',
#  'thou',
#  'contracted',
#  'to',
#  'thine',
#  'own',
#  'bright',
#  'eyes',
#  'feed',
#  'st',
#  'thy',
#  'light',
#  's',
#  'flame',
#  'with',
#  'self',
#  'substantial',
#  'fuel',
#  'making',
#  'a',
#  'famine',
#  'where',
#  'abundance',
#  'lies',
#  'thy',
#  'self',
#  'thy',
#  'foe',
#  'to',
#  'thy',
#  'sweet',
#  'self',
#  'too',
#  'cruel',
#  'thou',
#  'that',
#  'art',
#  'now',
#  'the',
#  'world',
#  's',
#  'fresh',
#  'ornament',
#  'and',
#  'only',
#  'herald',
#  'to',
#  'the',
#  'gaudy',
#  'spring',
#  'within',
#  'thine',
#  'own',
# ...

# %%
from collections import Counter

# %%
# 어떤 단어가 몇개가 있다라고 보여줌
tokens_cnt = Counter(tokens)
tokens_cnt
# Out:
# Counter({'and': 490,
#          'the': 432,
#          'to': 414,
#          'my': 393,
#          'of': 370,
#          'i': 351,
#          'that': 323,
#          'in': 323,
#          'thy': 287,
#          'thou': 235,
#          's': 202,
#          'love': 194,
#          'with': 181,
#          'for': 172,
#          'is': 170,
#          'not': 167,
#          'a': 164,
#          'me': 164,
#          'but': 163,
#          'thee': 162,
#          'so': 145,
#          'be': 142,
#          'as': 121,
#          'all': 120,
#          'you': 112,
#          'it': 111,
#          'which': 108,
#          'his': 107,
#          'when': 106,
#          'this': 105,
#          'your': 100,
#          'by': 94,
#          'self': 88,
#          'doth': 88,
#          'do': 84,
#          'from': 82,
#          'on': 80,
#          'or': 79,
#          'no': 79,
#          'have': 77,
#          'then': 74,
#          'what': 73,
#          'beauty': 70,
#          'time': 70,
# ...

# %%
# 딕셔너리로 변경, 순서는 랜덤으로
dict(tokens_cnt)
# Out:
# {'the': 432,
#  'sonnets': 1,
#  'by': 94,
#  'william': 1,
#  'shakespeare': 1,
#  'from': 82,
#  'fairest': 5,
#  'creatures': 2,
#  'we': 15,
#  'desire': 11,
#  'increase': 4,
#  'that': 323,
#  'thereby': 2,
#  'beauty': 70,
#  's': 202,
#  'rose': 6,
#  'might': 26,
#  'never': 16,
#  'die': 12,
#  'but': 163,
#  'as': 121,
#  'riper': 2,
#  'should': 44,
#  'time': 70,
#  'decease': 3,
#  'his': 107,
#  'tender': 7,
#  'heir': 3,
#  'bear': 13,
#  'memory': 8,
#  'thou': 235,
#  'contracted': 2,
#  'to': 414,
#  'thine': 44,
#  'own': 30,
#  'bright': 11,
#  'eyes': 53,
#  'feed': 2,
#  'st': 52,
#  'thy': 287,
#  'light': 7,
#  'flame': 3,
#  'with': 181,
#  'self': 88,
#  'substantial': 1,
#  'fuel': 1,
#  'making': 12,
#  'a': 164,
#  'famine': 1,
#  'where': 41,
#  'abundance': 4,
#  'lies': 12,
#  'foe': 1,
#  'sweet': 57,
#  'too': 18,
#  'cruel': 8,
#  'art': 52,
#  'now': 46,
#  'world': 33,
#  'fresh': 7,
#  'ornament': 5,
#  'and': 490,
#  'only': 6,
#  'herald': 1,
# ...

# %%
import pandas as pd

# %%
# 데이터를 사용하기 위해서 데이터 프레임으로 만들어서 사용할 예정이다.
token_df = pd.DataFrame.from_dict(tokens_cnt, orient="index", columns=["freq"])
token_df.index.name = "token"
token_df
# Out:
#              freq
# token
# the           432
# sonnets         1
# by             94
# william         1
# shakespeare     1
# ...           ...
# cool            1
# discased        1
# thrall          1
# heats           1
# cools           1
#
# [3086 rows x 1 columns]

# %%
# 빈도수 높은 순으로 정렬
token_df.sort_values(by="freq", ascending=False, inplace=True)
token_df
# Out:
#          freq
# token
# and       490
# the       432
# to        414
# my        393
# of        370
# ...       ...
# durst       1
# signs       1
# thunder     1
# predict     1
# cools       1
#
# [3086 rows x 1 columns]

# %%
# 그림으로 그려보자.
import matplotlib.pyplot as plt

# %%
ax = token_df.head(20).plot(kind="barh")
ax.invert_yaxis()

# %%
# %pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# %%
# 시각화로 많이 쓰이는지 확인해보자.
cloud = WordCloud(background_color="white", max_words=100)
visual = cloud.fit_words(tokens_cnt)

plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)

plt.imshow(visual.to_image())
