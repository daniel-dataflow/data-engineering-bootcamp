# %% [markdown]
# ### 좀 더 편리한 시각화 도구 : Seaborn
# - matplotlib의 기능과 스타일을 확장한 파이썬 시각화 도구
# - seaborn 라이브러리를 설치해야 하지만 (!pip install seaborn)
# - 아나콘다 배포반을 사용하는 경우 기본으로 설치되기 때문에 추가 설치 필요 없음
# - seaborn을 사용할 때 matplotlib도 같이 import 되어 있어야 함
# - 스타일 색상을 지원하기위해서 파렛트를 지원
# - 그래프는 대부분 matplotlib에 있는 그래프를 사용하고,
# - seaborn에  몇 가지 그래프가 더 추가되어 있음

# %% [markdown]
# #### 그래프 유형
# - plot()
# - histplot()
# - kdeplot()
# - boxplot()
# - swarmplot()
# - lmplot()
# - heatmap()

# %%
# 한 셀에서 여러 변수 출력코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# 경고 메시지 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 패키지 버전 변경하기 전에 버전 확인
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
import matplotlib
print(matplotlib.__version__)
import folium
print(folium.__version__)
# Out:
# 2.0.0
# 1.24.3
# 0.12.2
# 3.7.3
# 0.14.0

# %% [markdown]
# #### 패키지 버전 변경 : Anaconda Prompt에서 할 것
# pip install --upgrade pandas==2.0.0
# pip install --upgrade matplotlib==3.7.3
# pip install --upgrade seaborn==0.12.2
# pip install --upgrade folium==0.14.0

# %%
# # folium이 설치되어 있으면
# pip install folium==0.14.0

# # 버전이 변경되지 않으면 
# pip uninstall folium
# pip install folium==0.14.0

# %% [markdown]
# ### plot()

# %%
np.linspace(1,14,100)
# Out:
# array([ 1.        ,  1.13131313,  1.26262626,  1.39393939,  1.52525253,
#         1.65656566,  1.78787879,  1.91919192,  2.05050505,  2.18181818,
#         2.31313131,  2.44444444,  2.57575758,  2.70707071,  2.83838384,
#         2.96969697,  3.1010101 ,  3.23232323,  3.36363636,  3.49494949,
#         3.62626263,  3.75757576,  3.88888889,  4.02020202,  4.15151515,
#         4.28282828,  4.41414141,  4.54545455,  4.67676768,  4.80808081,
#         4.93939394,  5.07070707,  5.2020202 ,  5.33333333,  5.46464646,
#         5.5959596 ,  5.72727273,  5.85858586,  5.98989899,  6.12121212,
#         6.25252525,  6.38383838,  6.51515152,  6.64646465,  6.77777778,
#         6.90909091,  7.04040404,  7.17171717,  7.3030303 ,  7.43434343,
#         7.56565657,  7.6969697 ,  7.82828283,  7.95959596,  8.09090909,
#         8.22222222,  8.35353535,  8.48484848,  8.61616162,  8.74747475,
#         8.87878788,  9.01010101,  9.14141414,  9.27272727,  9.4040404 ,
#         9.53535354,  9.66666667,  9.7979798 ,  9.92929293, 10.06060606,
#        10.19191919, 10.32323232, 10.45454545, 10.58585859, 10.71717172,
#        10.84848485, 10.97979798, 11.11111111, 11.24242424, 11.37373737,
#        11.50505051, 11.63636364, 11.76767677, 11.8989899 , 12.03030303,
#        12.16161616, 12.29292929, 12.42424242, 12.55555556, 12.68686869,
#        12.81818182, 12.94949495, 13.08080808, 13.21212121, 13.34343434,
#        13.47474747, 13.60606061, 13.73737374, 13.86868687, 14.        ])

# %%
# 사용할 데이터 
np.linspace(1,14,100) #1부터 14까지의 범위에서 동일 간격의 숫자 100개 생성

x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2*np.sin(x+0.5)
y3 = 3*np.sin(x+1.0)
y4 = 4*np.sin(x+1.5)

# %%
# plot() 예 : 4개의 sin 곡선
plt.figure(figsize=(6,4))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()

# %% [markdown]
# #### seaborn 스타일링 함수
#
# 1. set_style() : 그림의 전반적인 모양 스타일링
#     - background color, grid, spine, tick 등 설정
#     - Built-in Themes (내장 테마) 활용
#     -  5가지 기본 제공 테마 : darkgrid, whitegrid, dark, white, ticks.
#         - 기본값은 darkgrid, 원하는대로 변경 가능
# 2. despine() 함수
#     - 축선 표시 여부 결정 (right=T/F,left=T/F,top=T/F,bottom=T/F)
#         - 각 속성값에 따라 표시 설정
#             - True  : 표시 안 함
#             - False : 표시
# 3. set_context() 함수
#     - 프리젠테이션이나 보고서와 같은 다양한 매체에 활용할 수 있도록 스타일링
#     - 전체 스케일 조정 : paper, notebook, talk, poster(기본값 : notebook)
#     - 스케일로도 전반적인 사이즈를 조정가능하지만, 폰트 크기 조정 파라미터 별도 사용 가능
#     - sns.set_context() 함수의 font_scale 파마미터 사용

# %%
# 스타일 설정 : 배경 설정 
# set_style() : darkgrid, whitegrid, dark, white, ticks)
sns.set_style('dark')
plt.figure(figsize=(6,4))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()

# %%
# 스타일 설정 : 축선 표시 despine()
# (right=T/F,left=T/F,top=T/F,bottom=T/F)
# True : 표시
# False : 표시 안 함
sns.set_style('whitegrid')
plt.figure(figsize=(6,4))
plt.plot(x,y1, x,y2, x,y3, x,y4)

sns.despine(left=True, bottom=True)
plt.show()

# %%
# style 설정 : set_context()
# paper, notebook, talk, poster
sns.set_context('notebook', font_scale=0.5) # style 설정 : font_scale
plt.figure(figsize=(6,4))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()

# %%
# titanic 데이터셋 사용

# %%
titanic = sns.load_dataset('titanic') 
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# 범주형 변수 (카테고리 변수) 시각화하는 그래프 : catplot()
# x 값만 지정
sns.catplot(x='class',
           kind='count',  # 빈도 막대그래프 그리기
           data=titanic)

# %%
sns.catplot(x='class',
           col='sex', # 성별(카테고리별)로 캔버스 분리
           kind='count',
           data=titanic)

# %%
# tips 데이터셋 사용

# %%
tips = sns.load_dataset('tips') 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# x : 범주형 변수, y : 연속값
sns.catplot(x='day', y='total_bill', data=tips)
# 점으로 표시

# %%
# 빈도수 시각화 하는 그래프 : coutplot()
sns.countplot(x='class', hue='sex',  data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ###  Distribution Plot
# - Distribution Plot은 데이터의 분포를 시각화하는데 도움이 되는 그래프
#     - 1. Hist Plot : histplot()
#     - 2. KDE Plot : kdeplot()
#     - 3. Box Plot : boxplot()
#     - 4. Swarm Plot : swarmplot()

# %% [markdown]
# #### 1. Hist Plot
# - 변수에 대한 히스토그램 표시
# - 하나 또는 두 개의 변수 분포를 나타내는 전형적인 시각화 도구로
# - 범위에 포함되는 관측수를 세어 표시

# %%
sns.histplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# KDE : 커널 밀도 추정 
# 연속된 곡선 그래프로 표시 
sns.histplot(x=tips['total_bill'], kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# 범주형 데이터 : 성별
sns.histplot(x=tips['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
# 범주형 데이터 : 요일별
sns.histplot(x=tips['day'])
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
# 연속형 값
sns.histplot(x=tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# 누적 막대로 표시
sns.histplot(x='sex',
            hue='survived',
            multiple='stack', # 누적 막대그래프로 표시
            data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
# 막대 간격을 조정해서 일반 막대그래프처럼 사용
# 간격 조정 : shrink 옵션 사용
sns.histplot(x='sex',
            hue='survived',
            multiple='stack', # 누적 막대그래프로 표시
            shrink=.77, 
            data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
# 수평 막대
sns.histplot(y='class',
            hue='survived',
            multiple='stack', # 누적 막대그래프로 표시
            shrink=.77, 
            data=titanic)
# Out:
# <Axes: xlabel='Count', ylabel='class'>

# %%
# 수평 다중 막대
sns.countplot(y='class',
            hue='sex',
            data=titanic)
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %% [markdown]
# 2. KDE Plot
# - Kernel Density Estimation (커널 밀도 추정)
# - 하나 또는 두 개의 변수에 대한 분포를 나타내는 그래프
# - histplot은 절대량이라면 kdeplot은 밀도 추정치를 시각화
#     - 연속된 곡선의 그래프로 출력

# %% [markdown]
# #### 밀도 추정 (density estimation)
# - 관측된 데이터들의 분포로부터 원래 변수의 (확률)분포 특성을 추정하는 것
# - 예 : 특정 지역의 이동인구 수
#   - 어떤 날은 10명
#   - 어떤 날은 100명
#   - 몇 명이라고 단정짓기 어려움
#   - 일정 기간(개월, 년) 동안 관측한 데이터들을 분석해서
#     - 분포 특성을 찾아내는 전체 과정을 밀도추정이라고 봄

# %%
# KDE Plo
sns.kdeplot(x=tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x=tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
# 정규분포와 비교해서 확인
from scipy import stats
sns.distplot(tips['total_bill'], fit=stats.norm)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# 주의! : 곡선 그래프에서 범주형 값 사용 시 에러
# sns.kdeplot(x=tips['sex'])
# The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %% [markdown]
# #### 3. Box Plot
# - 박스 플롯 (Box plot) : 전체 데이터로부터 얻어진 통계량 5가지 요약 수치로 그래프 생성
#     - 최소값 : 0% 지점
#     - 제 1사분위 수 (Q1 : 25% 지점)
#     - 제 2사분위 수 또는 중위수 (Q2 : 50% 지점)
#     - 제 3사분위 수 (Q3 : 75% 지점)
#     - 최대값 : 100% 지점
# - 최대, 최소, mean(평균), 사분위수를 보기 위한 그래프
# - 특이치(outliar)를 발견하기 좋음
# - 단일 연속형 변수에 대해 수치를 표시하거나,
# - 연속형 변수를 기반으로 서로 다른 범주형 변수를 분석할 수 있음

# %%
# total_bill 1개 데이터만 사용
sns.boxplot(x=tips['total_bill'])
# 방향 : x 축 (x 값만 지정)
# Out:
# <Axes: xlabel='total_bill'>

# %%
# total_bill 1개 데이터만 사용
sns.boxplot(y=tips['total_bill'])
# 방향 : y 축 (y 값만 지정)
# Out:
# <Axes: ylabel='total_bill'>

# %%
# x, y 값 지정
# 요일별 total_bill(영수증 금액)의 분포 확인

sns.boxplot(x=tips['day'], y=tips['total_bill'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 색상 변경 : palette 설정 
# palette = '파레트명'
sns.boxplot(x=tips['day'], y=tips['total_bill'], palette='RdBu')
# Set1, Set2, RdBu, RdYlGn
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 범주형 변수 처리
# 카테고리 값을 갖는 변수의 이름을 heu 인수에 지정
# 카테고리 값에 따라 다르게 시각화됨

# total_bill
# 범주형 변수 : smoker(Yes/No)
sns.boxplot(x='day', y='total_bill', data=tips, 
            hue='smoker', palette='Set1')

# 범례는 자동으로 빈 공간에 배치
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# 요일별 팁의 분포를 비교하는데, 성별에 따라 나누어서 박스 플롯으로 표시
sns.boxplot(x='day', y='tip', data=tips,
            hue='sex', palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# #### 4. Swarm Plot : swarmplot()
# - 데이터 포인트 수와 함께 각 데이터의 분포 표시 (점으로 표시)
# - 데이터가 모여 있는 정도를 확인하기 좋음

# %%
plt.figure(figsize=(6, 4))
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %%
# box plot과 swasrmplot을 같이 사용
plt.figure(figsize=(6, 4))
sns.boxplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, palette='husl')
plt.show()

# %% [markdown]
# ### lmplot()
# - 스캐터 그래프를 그릴때 회귀선을 기본으로 출력해주는 그래프 함수
# - 옵션
#     - x, y, data, palette
#     - height  : 그래프 크기
#         - size 사용시 오류 발생 : height로 변경해서 사용
#     - hue  : 카테고리 데이터를 분류하여 그룹화하되 하나의 그래프에 두개의 값을 모두 표현
#         - hue='sex' : 하나의 그래프에 male, female 표시
#     - col  : 카테고리 데이터를 분류하여 그룹화하되 그룹의 개수만큼 그래프를 생성해서 표현
#         - col='sex' : 2개의 그래프로 분리. male 그래프, female 그래프
#     - fit_reg=False : 회귀선 생략 가능
#     - ci = None : 신뢰구간 없음 (95:95% 신뢰구간)
#     - scatter_kws = {'s':50, 'alpha':1} : 점의 크기 및 투명도

# %% [markdown]
# ### 참고
# 회귀 분석
# - 하나 또는 그 이상의 독립변수와 종속변수에 대한 영향을 추정할 수 있는 통계 기법
# - 두 변수의 상관관계를 기본으로 하여
# - 하나의 1차 선형식으로 두 변수의 관계를 일반화하는 분석 방법
#
# 예:
#     - 독립변수가 종속변수에 영항을 미치는가?
#     - 독립변수가 1증가할 때 종속변수는 얼마나 증가할 것인가?
#
# 회귀선에서 가장 유용한 값은 기울기
# - 기울기 : 종속변수에 독립변수가 미치는 영향을 나타낸다
# - 기울기 클수록 종속변수에 미치는 영향, 관계의 정도가 커진다는 의미
# - 기울기 음(-)이라면 변화의 방향이 반대로 독립변수가 증가할 수록 종속변수는 감소하는 관계

# %%
# lmplot() : 산점도와 함께 선형 회귀선 표시
# 선 주변의  그림자 영역 : 회귀 추정한  값의 신뢰 구간의 영역 
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', data=tips, height=5)
plt.show()

# %%
# 참고 : regplot() 사용 (유사)
# 여러 옵션 다름 : size, height, hue 사용하면 오류
sns.set_style('darkgrid')
sns.regplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# 신뢰구간 영역 설정 : 일반적으로 95%로 설정
# ci 옵션 사용  
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', data=tips, height=5, ci=50)
plt.show()

# %%
# 회귀선 생략 가능 : git_reg=False
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', data=tips, height=5, fit_reg=False)
plt.show()

# %%
# 카테고리 변수 smoker가 포함된 경우의 회귀선
# hue='smoker' 설정
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips, height=5,
          scatter_kws={'s':20, 'alpha':0.6}, palette="Set1")
plt.show()

# 점 크기 및 투명도 설정 가능

# %%
# 범주형 변수 사용 시 겹치지 않고 별도 그래프로 표시 : col=범주형값
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips, height=5,
          scatter_kws={'s':20, 'alpha':0.6}, palette="Set1",
          col='smoker')
plt.show()

# %%
# 범주형 변수 사용 시 겹치지 않고 별도 그래프로 표시 : col=범주형값
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips, height=5,
          scatter_kws={'s':20, 'alpha':0.6}, palette="Set1",
          col='day')
plt.show()

# %%
# 카테고리 값이 많은 경우 아래로 배치 가능 : col_wrap 옵션
# col_wrap=2
sns.set_style('darkgrid')
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips, height=5,
          scatter_kws={'s':20, 'alpha':0.6}, palette="Set1",
          col='day', col_wrap=2)
plt.show()

# %% [markdown]
# ### heatmap 그래프
# - 히트맵 (heat map)
#     - 열분포도
#     - 2차원 수치 데이터를 색으로 표시
#         - 집계한 값에 비례해서 색상을 다르게 하여 2차원으로 데이터를 시각화하는 방법
#     - 두개의 카테고리 값에 대한 값 변화를 한 눈에 알기 쉬움
#     - 대용량 데이터 시각화에도 많이 사용됨
#
# sns.heatmap()
# - annot = True :  숫자 표시 여부 <br>
# - ax = ax :  히트맵을 그릴 격자 <br>
# - linewidths = 0.4, : 선의 굵기 <br>
# - linecolor = 'white' : 선의 색깔 <br>
# - fmt = '.1f' :  소수점 포맷팅 형태 <br>
# - cmap = 'YlOrRd' :  colormap 형태

# %%
# heamap()에 사용할 데이터셋 : 항공기 승객수 데이터셋 사용
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.to_csv('../data/flights.csv')

# %%
# 연도별, 월별 항공기 승객 수 출력
# pivot_table() 사용해서 변환
# 행 인덱스 : 월
# 열 인덱스 : 연도 

flights.pivot_table(index='month', columns='year')
# Out:
#       passengers
# year        1949 1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960
# month
# Jan          112  115  145  171  196  204  242  284  315  340  360  417
# Feb          118  126  150  180  196  188  233  277  301  318  342  391
# Mar          132  141  178  193  236  235  267  317  356  362  406  419
# Apr          129  135  163  181  235  227  269  313  348  348  396  461
# May          121  125  172  183  229  234  270  318  355  363  420  472
# Jun          135  149  178  218  243  264  315  374  422  435  472  535
# Jul          148  170  199  230  264  302  364  413  465  491  548  622
# Aug          148  170  199  242  272  293  347  405  467  505  559  606
# Sep          136  158  184  209  237  259  312  355  404  404  463  508
# Oct          119  133  162  191  211  229  274  306  347  359  407  461
# Nov          104  114  146  172  180  203  237  271  305  310  362  390
# Dec          118  140  166  194  201  229  278  306  336  337  405  432

# %%
flights_pv = flights.pivot_table(values='passengers', index='month', columns='year')
flights_pv
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# heatmap() 사용해서 그래프 그리기
plt.figure(figsize=(6,4))
sns.heatmap(flights_pv)
plt.show()
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
# 각 셀에 숫자 출력 : annot=True 설정
# fmt = 'f' : 포맷 (실수)
# fmt = 'd' : 포맷 (정수)
plt.figure(figsize=(10,6))
# sns.heatmap(flights_pv, annot=True, fmt='.2f') # 정수인데 소수점이하 2자리 지정해도 오류 없음
sns.heatmap(flights_pv, annot=True, fmt='d')
plt.show()

# 주의! : 실수값인 경우 fmt='d'하면 오류
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
# cmap 설정
plt.figure(figsize=(10,6))
# sns.heatmap(flights_pv, annot=True, fmt='.2f') # 정수인데 소수점이하 2자리 지정해도 오류 없음
sns.heatmap(flights_pv, annot=True, fmt='d', cmap='RdBu')
plt.show()
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ### 상관 행렬을 통한 heatmap 활용 : 상관관계 시각화
# - df.corr() 사용하여 상관 행렬 구한 후
# - heatmap()으로 상관관계 시각화

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# 상관계수 구해서 출력 : corr() 사용
# 상관계수 구하는 corr()에서 문자값  포함되면 오류 
# 수치값이 아닌 값을  포함하는 열이 있으면 오류 
# tips에는 카테고리 타입 열 포함되어 있으므로
# 카테고리 타입의 열 제외하고 상관계수 구하기

cgs_cols = tips.select_dtypes(include=['category']).columns
new_tips = tips.drop(columns=cgs_cols)
new_tips
# 수치값 열만 포함하는 df 생성
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
# 상관계수 구하기 : 상관행렬 생성 (df로 반환)
new_tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# 상관계수 값을 heatmap으로 표시 
plt.figure(figsize=(6,4))
sns.heatmap(new_tips.corr(), annot=True, fmt='f', cmap='viridis')
plt.show()

# 색상이 밝을수록 상관관계 높음
# Out:
# <Axes: >

# %% [markdown]
# #### pairplot()
# - 데이터 셋 전체를 입력으로 넣어서 수치형 변수들끼리 상관 매트릭스를 표현
# - 각 그리드의 두 변수 간의 관계를 나타내는 그래프 표시
# - 그리드 형태로 각 데이터의 열의 조합에 대해 스케터 플롯을 그린다
# - 3차원 이상의 데이터에 적용
# - 같은 데이터가 만나는 대각선 영역에는 해당 데이터의 히스토그램을 그린다
# - 대각선 위와 아래는 축만 바꾼것이므로 한쪽만 확인하면 됨
# - 선형적인 관계로 보이는 그래프 확인

# %%
# 아이리스 꽃 (붓꽃) 데이터 사용
# 꽃잎 (petal), 꽃받침(sepal)의 너비와 폭으로 종 구분
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 스타일적용
sns.set(style='ticks')

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %%
sns.pairplot(iris, hue='species', diag_kind='hist')
plt.show()

# %%
sns.pairplot(iris, diag_kind='kde')
plt.show()

# %%
sns.pairplot(iris, hue='species', diag_kind='kde') # 디폴트
plt.show()

# %% [markdown]
# # folium  패키지
# - 지도 이용해 data 시각화 하는 도구
# - 아나콘다 프롬프트에서 설치
#     - pip install folium : 주로 사용
#     - pip install folium
# - OPEN STREET MAP과 같은 지도 데이터에 leaflet.js 를 이용해서 위치 정보를 시각화 하기 위한 라이브러리
# - 마커형태로 위치정보를 지도상에 표현할 수 있다

# %%
import folium

# %%
print(folium.__version__)
# Out:
# 0.14.0

# %% [markdown]
# #### 지도 생성 방법
# - Map() 메소드에 중점 좌표값을 지정해서 간단하게 지도 생성
# - 위도와 경도로 위치로 지도 그려줌
#
# - 중심좌표 인수 : location=[위도, 경도]
#     - 위도(latitude)와 경도(longitude)
# - 확대비율 정의 인수 : zoon_start=13
#
# ---
# - Open Street  Map을 기반으로 동작하고
# - 내부적으로 스타일 2개를 지원
#      - tiles= Stamen Toner/ Stamen Terrain 였는데
#      - CartoDB position, CartoDB dark_matter로 변경됨

# %%
# Open Street Ma 기반 지도 
# 맨해튼 : 위도: 40.6643, 경도: -73.9385
smap = folium.Map(location=[40.664, -73.9385], zoom_start=13)
smap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfef2fb0dd7d30e4cbb935d9e241c73a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfef2fb0dd7d30e4cbb935d9e241c73a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfef2fb0dd7d30e4cbb935d9e241c73a = L.map(
#                 &quot;map_cfef2fb0dd7d30e4cbb935d9e241c73a&quot;,
#                 {
#                     center: [40.664, -73.9385],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4c3b21d6dce040788ad6c4f5845b91e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cfef2fb0dd7d30e4cbb935d9e241c73a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###

# %%
import folium

# %%
# 배경지도 타일 설정
# 맨해튼 : 위도: 40.6643, 경도: -73.9385
smap = folium.Map(location=[40.6643, -73.9385], zoom_start=13)
folium.TileLayer('cartodbpositron').add_to(smap)
smap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7277d2f7cf029a02549c6d743af32430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7277d2f7cf029a02549c6d743af32430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7277d2f7cf029a02549c6d743af32430 = L.map(
#                 &quot;map_7277d2f7cf029a02549c6d743af32430&quot;,
#                 {
#                     center: [40.6643, -73.9385],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79b685092edf98d8847c1f680bd0bb86 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7277d2f7cf029a02549c6d743af32430);
#
#
#             var tile_layer_b885904bd278f3389c60f8f54295ecc3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7277d2f7cf029a02549c6d743af32430);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
smap = folium.Map(location=[40.6643, -73.9385], zoom_start=13)
folium.TileLayer('cartodbdark_matter').add_to(smap)
smap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a84d8933c9820b027577b5facf9bc600 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a84d8933c9820b027577b5facf9bc600&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a84d8933c9820b027577b5facf9bc600 = L.map(
#                 &quot;map_a84d8933c9820b027577b5facf9bc600&quot;,
#                 {
#                     center: [40.6643, -73.9385],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1df2f023c225cccd5e7244ddf4c8d4dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a84d8933c9820b027577b5facf9bc600);
#
#
#             var tile_layer_58b90a198ff97ed36c6f7fe1cb41fb16 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a84d8933c9820b027577b5facf9bc600);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 마커 및 popup 설정
#     - 마커(특정 위치를 표시하는 표식)
#     - popup(마커 클릭시에 나타나는 정보) : 환경에 따라 지원안되는 경우도 있음
#
# 1. 마커 생성
#     - folium.Marker(): 위,경도 값 리스트, popup, icon 설정
#     - 서클 마커 : CircleMarker() : 위,경도 값 리스트, popup, radius, color, fill_color
# 2. 마커 생성 후 지도에 부착
#     - folium.Marker().add_to(지도객체변수)
#     - folium.CircleMarker().add_to(지도객체변수)

# %%
# 서울특별시청 
# 위도 : 37.566345
# 경도 : 126.977893
seoul_cityhall_map = folium.Map(location=[37.566345, 126.977893], zoom_start=17)
seoul_cityhall_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2847f548e0166b2b6d23423dcc1679ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2847f548e0166b2b6d23423dcc1679ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2847f548e0166b2b6d23423dcc1679ac = L.map(
#                 &quot;map_2847f548e0166b2b6d23423dcc1679ac&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25fde8542a2f81fa28be980002fdaf2d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2847f548e0166b2b6d23423dcc1679ac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 서울시청 지도에 마커 표시 
# popup 출력 : '서울 시정'

# 덕수궁에 서클마커 표시
# popup 출력 : '덕수궁'
# 덕수궁 : 37.5658049,  126.975146000007

seoul_cityhall_map = folium.Map(location=[37.566345, 126.977893], zoom_start=17)

# 서울시청에 마커 표시 및 팝업 출력
folium.Marker([37.566345, 126.977893], popup='시청').add_to(seoul_cityhall_map)

# 덕수궁에 서클마크 표시 및 팝업 출력
folium.CircleMarker([37.5658049, 126.975146000007], 
                    popup='덕수궁',
                    radius=50,
                    color='red',
                    fill_color='blue').add_to(seoul_cityhall_map)

seoul_cityhall_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51ba8544f8bf4f9cefb8fc2cb45e3089 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51ba8544f8bf4f9cefb8fc2cb45e3089&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51ba8544f8bf4f9cefb8fc2cb45e3089 = L.map(
#                 &quot;map_51ba8544f8bf4f9cefb8fc2cb45e3089&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c854e3430babf28d597133757b666bf2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_51ba8544f8bf4f9cefb8fc2cb45e3089);
#
#
#             var marker_cc0c4cb675e8f00523f94df5b8760975 = L.marker(
#                 [37.566345, 126.977893],
#                 {}
#             ).addTo(map_51ba8544f8bf4f9cefb8fc2cb45e3089);
#
#
#         var popup_fbc6f3a45c15dc7b3b7a18f999c94b0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c960e2744bf33383ec50b31418eb977f = $(`&lt;div id=&quot;html_c960e2744bf33383ec50b31418eb977f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;시청&lt;/div&gt;`)[0];
#                 popup_fbc6f3a45c15dc7b3b7a18f999c94b0e.setContent(html_c960e2744bf33383ec50b31418eb977f);
#
#
#
#         marker_cc0c4cb675e8f00523f94df5b8760975.bindPopup(popup_fbc6f3a45c15dc7b3b7a18f999c94b0e)
#         ;
#
#
#
#
#             var circle_marker_f758379785026869d8adeb89cd8188c8 = L.circleMarker(
#                 [37.5658049, 126.975146000007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51ba8544f8bf4f9cefb8fc2cb45e3089);
#
#
#         var popup_db864ec0c18edf77cf5d48e4df8a7cd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6abb23b507979e2cea947995c6c01301 = $(`&lt;div id=&quot;html_6abb23b507979e2cea947995c6c01301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_db864ec0c18edf77cf5d48e4df8a7cd1.setContent(html_6abb23b507979e2cea947995c6c01301);
#
#
#
#         circle_marker_f758379785026869d8adeb89cd8188c8.bindPopup(popup_db864ec0c18edf77cf5d48e4df8a7cd1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 단계 구분도
# - 데이터를 지도 그림에 반영시켜서 전달하는 그래프
# - 보통 folium 에 layer로 올려서 표시
# - map 객체의 choropleth() 이용
# - 사용 인수
#     - geo_data : 지도 파일 경로와 파일명
#     - data : 지도에 표현되어야 할 값 변수
#     - columns =  [key로 사용할 data, 실제 data의 필드명]
#     - key_on : 지도 경계파일인 json에서 사용할 키 값이며 지도 Data는 표준 형식으로 만들어 져야 함
#         - key_on 지칭 문법 : feature(키워드).json에서 나타나키 필드명
# - folium.LayerControl().add_to(map)  : 단계구분도를 map에 표시하는 함수

# %%
# 단계 구분도에서 사용할 data : population.csv 파일에서 읽어 오기
# 구별 CCTV 인구수
cctv_df = pd.read_csv('../data/population.csv', index_col='구별')
cctv_df
# Out:
#                소계
# 구별
# 종로구    150.619195
# 중 구    166.490765
# 용산구    125.203252
# 성동구    134.793814
# 광진구   2109.000000
# 동대문구    53.228621
# 중랑구     64.973730
# 성북구    100.000000
# 강북구    188.929889
# 도봉구    246.638655
# 노원구   1870.000000
# 은평구    139.338235
# 서대문구   212.101911
# 마포구   1254.000000
# 양천구     63.371266
# 강서구     81.780822
# 구로구     63.627354
# 금천구    104.347826
# 영등포구    34.671731
# 동작구   1277.000000
# 관악구     53.216374
# 서초구   2108.000000
# 강남구    248.922414
# 송파구   1023.000000
# 강동구     79.960707

# %%
# 서울시 지도 데이터 이용해서 단계 구분도 작성

# 서울시 지도 구별 경계 값을 갖고 있는 json data 파일 사용
# json.load() 사용
# 한글이 포함된 경우에는 path만 연결하면 인코딩 문제 발생 
# encoding='utf-8' 지정

import json
geo_path = '../data/skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
# geo_str

# %%
# 서울을 중심으로 기본지도 출력
# street map 생성
seoul_map = folium.Map(location=[37.5502, 126.982])
# seoul_map

# street map 위에 pop_df 데이터로 단계 구분도를 그리기
seoul_map.choropleth(geo_data=geo_str,
                    data=cctv_df,
                    columns=[cctv_df.index, '소계'],
                    key_on='feature.id',
                    fill_color="PuRd",
                    legend_name='CCTV 소계')

folium.LayerControl().add_to(seoul_map)

seoul_map.save('../data/seoul_map_cctv.html')

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3953c47a8a6ab1f4bf1b38a7a373cd7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3953c47a8a6ab1f4bf1b38a7a373cd7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3953c47a8a6ab1f4bf1b38a7a373cd7a = L.map(
#                 &quot;map_3953c47a8a6ab1f4bf1b38a7a373cd7a&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_605a4d8254f225df3eabdb3b97ad1c43 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3953c47a8a6ab1f4bf1b38a7a373cd7a);
#
#
#             var tile_layer_0c312814258cf5c70a482633d937af03 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3953c47a8a6ab1f4bf1b38a7a373cd7a);
#
#
#             var choropleth_55af5444d32735d2b5c748f7458b5386 = L.featureGroup(
#                 {}
#             ).addTo(map_3953c47a8a6ab1f4bf1b38a7a373cd7a);
#
#
#         function geo_json_d06ea9d300409a03f7a8c15fc68a905a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d06ea9d300409a03f7a8c15fc68a905a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d06ea9d300409a03f7a8c15fc68a905a = L.geoJson(null, {
#                 onEachFeature: geo_json_d06ea9d300409a03f7a8c15fc68a905a_onEachFeature,
#
#                 style: geo_json_d06ea9d300409a03f7a8c15fc68a905a_styler,
#         });
#
#         function geo_json_d06ea9d300409a03f7a8c15fc68a905a_add (data) {
#             geo_json_d06ea9d300409a03f7a8c15fc68a905a
#                 .addData(data)
#                 .addTo(choropleth_55af5444d32735d2b5c748f7458b5386);
#         }
#             geo_json_d06ea9d300409a03f7a8c15fc68a905a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&q
